# %%
#Ex 1,2,3
class Restaurant:

    def __init__(self, restaurant_name, cuisine_type, customers_served=0):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        self.customers_served = customers_served

    def describe_restaurant(self):
        print(f"{self.restaurant_name} is of type {self.cuisine_type}.\n Number of people served today: {self.customers_served} ")
    
    def open_restaurant(self):
        print(f"{self.restaurant_name} is now open")

    def set_number_of_customers_served(self, amount):
        self.customers_served = amount
        self.describe_restaurant()

    def increment_customers_served(self):
        self.customers_served +=1
        self.describe_restaurant()

# restaurant = Restaurant("Pizza_paradisio","Pizzeria" )
# print(restaurant.restaurant_name)
# print(restaurant.cuisine_type)
# restaurant.describe_restaurant()
# restaurant.open_restaurant()

# restaurant2 = Restaurant("KKKebula", "Kebabila")
# restaurant3 = Restaurant("Pihvii", "Steakhouse")
# restaurant2.describe_restaurant()
# restaurant3.describe_restaurant()

r4 = Restaurant("Luigi's", "Fine dining")
r4.set_number_of_customers_served(5)
r4.increment_customers_served()

# %%
#Ex 2
restaurant2 = Restaurant("KKKebula", "Kebabila")
restaurant3 = Restaurant("Pihvii", "Steakhouse")
restaurant2.describe_restaurant()
restaurant3.describe_restaurant()

# %%
#Ex 4,5

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

    def get_name(self):
        info = f"{self.year} {self.make} {self.model}"
        return info

    def read_odomoter(self):
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odomoter(self, mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage

    def increment_odometer(self, miles):
        self.odometer_reading += miles

    def fill_gas_tank(self):
        print(f"Filling gas tank on {self.year}{self.make}{self.model}.")       

class ElectricCar(Car): # Sulkuihin (Car) niin perii Car luokan
    def __init__(self, make, model, year, battery_size=75):
        super().__init__(make, model, year)
        self.battery_size = battery_size

    def describe_battery(self):
        print(f"This car has {self.battery_size} kWh bathory(!).")

    def fill_gas_tank(self):
        print(f"{self.year}{self.make}{self.model} has no gas tank!")

tesla = ElectricCar("Tesla", "Model S", 2019)



name = tesla.get_name()
print(name)
print(tesla.get_name())
tesla.read_odomoter()
tesla.increment_odometer(50)
tesla.read_odomoter()
tesla.update_odomoter(500)
tesla.read_odomoter()
tesla.describe_battery()
print(tesla.battery_size)

# %%
# Ex 6,7

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

class ElectricCar(Car): # Sulkuihin (Car) niin perii Car luokan
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery = Battery()

    def get_range(self):
        if self.battery.battery_size == 75:
            range = 260
        elif self.battery.battery_size == 100:
            range = 300
        print(f"This car can go about {range} miles on a full charge.")

class Battery:
    def __init__(self, battery_size=75):
        self.battery_size = battery_size
    def describe_battery(self):
        print(f"This car has {self.battery_size} kWh bathory(!).")

tesla = ElectricCar("Tesla", "Model S", 2019)
tesla.battery.describe_battery()
tesla.get_range()

# %%
# Ex 8,9    

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

class ElectricCar(Car): # Sulkuihin (Car) niin perii Car luokan
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery = Battery(model)

class Battery:
    def __init__(self,model, battery_size=75):
        self.model = model
        self.battery_size = battery_size

    def describe_battery(self):
        print(f"This car has {self.battery_size} kWh Bathory(!).")
    
    def get_range(self):
        if self.battery_size == 75:
            range = 250
        else:
            range = 300
        print(f"This car can go about {range} miles on a full charge.")
    
    def upgrade_battery(self):
        if self.battery_size != 100:
            self.battery_size = 100

tesla = ElectricCar("Tesla", "Model S", 2019)
tesla.battery.describe_battery()
tesla.battery.get_range()
tesla.battery.upgrade_battery()
tesla.battery.get_range()

# %%
# Ex 10

class Restaurant:
    def __init__(self, restaurant_name, cuisine_type, customers_served=0):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type
        self.customers_served = customers_served

    def describe_restaurant(self):
        print(f"{self.restaurant_name} is of type {self.cuisine_type}.\n Number of people served today: {self.customers_served} ")
    
    def open_restaurant(self):
        print(f"{self.restaurant_name} is now open")

    def set_number_of_customers_served(self, amount):
        self.customers_served = amount
        self.describe_restaurant()

    def increment_customers_served(self):
        self.customers_served +=1
        self.describe_restaurant()

class IceScreamStand(Restaurant):
    def __init__(self, restaurant_name, cuisine_type, customers_served=0):
        super().__init__(restaurant_name, cuisine_type, customers_served)
        self.flavors = ['Mango', 'Liqourice', 'Strawberry']

    def get_flavors(self):
        print(self.flavors)

kiosk = IceScreamStand("I Scream","Kiosk" )
kiosk.get_flavors()
# Out:
# ['Mango', 'Liqourice', 'Strawberry']
